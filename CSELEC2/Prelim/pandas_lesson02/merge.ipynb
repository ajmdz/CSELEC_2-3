# %%
import pandas as pd
df1= pd.DataFrame({
    "city": ["cebu", "manila", "qc"],
    "temperature": [29, 35, 31],
})
df1
# Out:
#      city  temperature
# 0    cebu           29
# 1  manila           35
# 2      qc           31

# %%
df2= pd.DataFrame({
    "city": ["cebu", "manila", "qc"],
    "temperature": [55, 65, 66],
})
df2
# Out:
#      city  temperature
# 0    cebu           55
# 1  manila           65
# 2      qc           66

# %%
df3 = pd.merge(df1, df2, on="city")
df3
# Out:
#      city  temperature_x  temperature_y
# 0    cebu             29             55
# 1  manila             35             65
# 2      qc             31             66

# %%
df1= pd.DataFrame({
    "city": ["cebu", "manila", "qc", "pasig"],
    "temperature": [29, 35, 31, 33],
})
df1
# Out:
#      city  temperature
# 0    cebu           29
# 1  manila           35
# 2      qc           31
# 3   pasig           33

# %%
df2= pd.DataFrame({
    "city": ["cebu", "manila", "qc"],
    "humidity": [65, 70, 73],
})
df2
# Out:
#      city  humidity
# 0    cebu        65
# 1  manila        70
# 2      qc        73

# %%
df3 = pd.merge(df1,df2,on="city",how='inner')
df3
# Out:
#      city  temperature  humidity
# 0    cebu           29        65
# 1  manila           35        70
# 2      qc           31        73

# %%
df3 = pd.merge(df1,df2,on="city",how='outer')
df3
# Out:
#      city  temperature  humidity
# 0    cebu           29      65.0
# 1  manila           35      70.0
# 2      qc           31      73.0
# 3   pasig           33       NaN

# %%
df3 = pd.merge(df1,df2,on="city",how='left')
df3
# Out:
#      city  temperature  humidity
# 0    cebu           29      65.0
# 1  manila           35      70.0
# 2      qc           31      73.0
# 3   pasig           33       NaN

# %%
df3 = pd.merge(df1,df2,on="city",how='right')
df3
# Out:
#      city  temperature  humidity
# 0    cebu           29        65
# 1  manila           35        70
# 2      qc           31        73

# %%
df3 = pd.merge(df1,df2,on="city",how='outer', indicator=True)
df3
# Out:
#      city  temperature  humidity     _merge
# 0    cebu           29      65.0       both
# 1  manila           35      70.0       both
# 2      qc           31      73.0       both
# 3   pasig           33       NaN  left_only

# %%
df1= pd.DataFrame({
    "city": ["cebu", "manila", "qc", "pasig"],
    "temperature": [29, 35, 31, 33],
    "humidity": [55,65,70,73]
})
df1
# Out:
#      city  temperature  humidity
# 0    cebu           29        55
# 1  manila           35        65
# 2      qc           31        70
# 3   pasig           33        73

# %%
df2= pd.DataFrame({
    "city": ["manila", "cebu", "tanauan",],
    "temperature": [29, 35, 31],
    "humidity": [55,65,70]
})
df2
# Out:
#       city  temperature  humidity
# 0   manila           29        55
# 1     cebu           35        65
# 2  tanauan           31        70

# %%
df3 = pd.merge(df1,df2,on="city",how='outer',suffixes=('_first','_second'))
df3
# Out:
#       city  temperature_first  humidity_first  temperature_second  \
# 0     cebu               29.0            55.0                35.0
# 1   manila               35.0            65.0                29.0
# 2       qc               31.0            70.0                 NaN
# 3    pasig               33.0            73.0                 NaN
# 4  tanauan                NaN             NaN                31.0
#
#    humidity_second
# 0             65.0
# 1             55.0
# 2              NaN
# 3              NaN
# 4             70.0

# %%
df1= pd.DataFrame({
    "city": ["cebu", "manila", "qc", "pasig"],
    "temperature": [29, 35, 31, 33],
})
df1.set_index('city', inplace=True)
df1
# Out:
#         temperature
# city
# cebu             29
# manila           35
# qc               31
# pasig            33

# %%
df2= pd.DataFrame({
    "city": ["cebu", "qc", "manila", "pasig"],
    "temperature": [29, 35, 31, 33],
})
df2.set_index('city', inplace=True)
df2
# Out:
#         temperature
# city
# cebu             29
# qc               35
# manila           31
# pasig            33

# %%
df1.join(df2,lsuffix='_l', rsuffix='_r')
# Out:
#         temperature_l  temperature_r
# city
# cebu               29             29
# manila             35             31
# qc                 31             35
# pasig              33             33
